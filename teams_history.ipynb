# %%
from utils import get_nba_season
from pandas import DataFrame
import pandas as pd
from teams_history import EAST_CITIES, WEST_CITIES

# %%
file_path = "data/archive/TeamHistories.csv"  

teams_histories = pd.read_csv(file_path)
teams_histories["seasonFounded"] = teams_histories["seasonFounded"].astype("int64")
teams_histories["seasonActiveTill"] = teams_histories["seasonActiveTill"].astype(
    "int64"
)
